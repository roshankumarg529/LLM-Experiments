# %% [markdown]
# <a href="https://colab.research.google.com/github/roshankumarg529/LLM-Experiments/blob/main/cuda_torch_workflow.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch
import torch.nn as nn

model = nn.Linear(10, 2)

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# load model weights to the GPU
model = model.to(device)

inputs = torch.randn(5,10)

# Copy inputs data from CPU to GPU
inputs = inputs.to(device)

# Launch GPU kernels (handled automatically by PyTorch)
outputs = model(inputs)

# Copy results back from GPU to CPU if needed
outputs_cpu = outputs.cpu()

print(outputs_cpu)
# Out:
# tensor([[ 0.5360, -0.2747],
#         [-0.3487,  0.1482],
#         [ 1.5059, -1.2385],
#         [ 1.3253, -0.2845],
#         [-0.1413,  0.5197]], grad_fn=<ToCopyBackward0>)

# %%
outputs
# Out:
# tensor([[ 0.5360, -0.2747],
#         [-0.3487,  0.1482],
#         [ 1.5059, -1.2385],
#         [ 1.3253, -0.2845],
#         [-0.1413,  0.5197]], device='cuda:0', grad_fn=<AddmmBackward0>)

# %%
inputs
# Out:
# tensor([[-0.7855, -0.9117,  1.2080, -0.8651,  0.6414,  1.1528,  1.1716, -1.6039,
#          -1.7180,  0.5335],
#         [-1.7191,  0.1356, -0.0283, -0.4263, -0.7875, -1.3561,  0.8682, -0.5194,
#          -0.6016,  0.4236],
#         [-3.4362, -1.1073, -0.1611, -2.8181, -0.3410,  0.9797,  0.9789, -1.1209,
#           0.6637, -1.3006],
#         [-1.1765, -1.2182,  1.5668, -0.5606, -0.5147,  0.8266,  0.0317, -1.4717,
#           2.3328, -0.7853],
#         [ 0.7467, -0.9271,  0.2417,  1.0298,  0.1944, -0.0350,  0.5779,  0.3634,
#          -0.6224,  0.0618]], device='cuda:0')

# %%
# !nvidia-smi
# Out:
# Thu Jun 18 17:42:37 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 580.82.07              Driver Version: 580.82.07      CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   59C    P0             30W /   70W |     139MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI              PID   Type   Process name                        GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |    0   N/A  N/A            2857      C   /usr/bin/python3                        136MiB |
# +-----------------------------------------------------------------------------------------+

# %%
# !nvidia-smi
# Out:
# Fri Jul 24 12:11:03 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 580.82.07              Driver Version: 580.82.07      CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   59C    P0             28W /   70W |     153MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI              PID   Type   Process name                        GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |    0   N/A  N/A            1512      C   /usr/bin/python3                        150MiB |
# +-----------------------------------------------------------------------------------------+

# %%
# %%writefile cuda_example.cu
#
# #include <stdio.h>
# #include <cuda_runtime.h>
#
# __global__ void myKernel(float *input, float *output) {
#     int idx = threadIdx.x;
#     output[idx] = input[idx] * 2;
# }
#
# int main() {
#     printf("Program started\n");
#
#     float h_input[10];
#     float h_output[10];
#
#     for(int i = 0; i < 10; i++)
#         h_input[i] = i;
#
#     float *d_input, *d_output;
#
#     printf("Allocating GPU memory\n");
#     cudaMalloc(&d_input, 10 * sizeof(float));
#     cudaMalloc(&d_output, 10 * sizeof(float));
#
#     printf("Copying data to GPU\n");
#     cudaMemcpy(d_input, h_input, 10 * sizeof(float), cudaMemcpyHostToDevice);
#
#     printf("Launching kernel\n");
#     myKernel<<<1,10>>>(d_input, d_output);
#     cudaDeviceSynchronize();
#
#     printf("Copying result back to CPU\n");
#     cudaMemcpy(h_output, d_output, 10 * sizeof(float), cudaMemcpyDeviceToHost);
#
#     printf("Results:\n");
#     for(int i = 0; i < 10; i++)
#         printf("%f\n", h_output[i]);
#
#     cudaFree(d_input);
#     cudaFree(d_output);
#
#     printf("Program finished\n");
#
#     return 0;
# }
# Out:
# Overwriting cuda_example.cu

# %%
# !nvcc cuda_example.cu -o cuda_example
# !./cuda_example
# Out:
# nvcc warning : Support for offline compilation for architectures prior to '<compute/sm/lto>_75' will be removed in a future release (Use -Wno-deprecated-gpu-targets to suppress warning).
# Program started
# Allocating GPU memory
# Copying data to GPU
# Launching kernel
# Copying result back to CPU
# Results:
# 0.000000
# 2.000000
# 4.000000
# 6.000000
# 8.000000
# 10.000000
# 12.000000
# 14.000000
# 16.000000
# 18.000000
# Program finished
